# %% [markdown]
# Comprendre Contraste Linear regression
# load boston
# set up boston for linear regression

# %% [markdown]
# # Package

# %%
import pandas as pd 
from set_up_ml import transform_df_for_model, summarize
import statsmodels.api as sm
Boston = pd.read_csv('data/Boston.csv')
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
X = transform_df_for_model(Boston,['lstat']) #X just extract lstat variable from df and add an intercept variable
y = Boston['medv']
model = sm.OLS(y, X)
results = model.fit()
print(summarize(results))
# Out:
#               coef  std err       t  P>|t|
# intercept  34.5538    0.563  61.415    0.0
# lstat      -0.9500    0.039 -24.528    0.0

# %%
import numpy as np
np.random.seed(42)  # optionnel, pour reproductibilité
gender_array = np.random.choice(['female', 'male'], size=X.shape[0])
Boston['gender'] = gender_array
X = transform_df_for_model(Boston,['gender'],contrast='drop') #X just extract lstat variable from df and add an intercept variable
y = Boston['medv']
model = sm.OLS(y, X)
results = model.fit()
print(summarize(results))
X
# Out:
#                  coef  std err       t  P>|t|
# intercept     22.4972    0.583  38.561  0.000
# gender[male]   0.0701    0.819   0.086  0.932
#      intercept  gender[male]
# 0          1.0             0
# 1          1.0             1
# 2          1.0             0
# 3          1.0             0
# 4          1.0             0
# ..         ...           ...
# 501        1.0             0
# 502        1.0             0
# 503        1.0             1
# 504        1.0             0
# 505        1.0             0
#
# [506 rows x 2 columns]

# %%
X = transform_df_for_model(Boston,['gender'],contrast='sum') #X just extract lstat variable from df and add an intercept variable
y = Boston['medv']
model = sm.OLS(y, X)
results = model.fit()
print(summarize(results))
# Out:
#                    coef  std err       t  P>|t|
# intercept       22.5323    0.409  55.049  0.000
# gender[female]  -0.0351    0.409  -0.086  0.932

# %%
df = pd.DataFrame({'intercept': np.ones(Boston.shape[0])}) #X just extract lstat variable from df and add an intercept variable
y = Boston['medv']
model = sm.OLS(y, df)
results = model.fit()
print(summarize(results))
# Out:
#               coef  std err       t  P>|t|
# intercept  22.5328    0.409  55.111    0.0

# %%
y.mean()
# Out:
# np.float64(22.532806324110677)

# %% [markdown]
# linear + Lasso

# %% [markdown]
# # Load the boston dataset

# %%
import pandas as pd
Hitters = pd.read_csv("data/Hitters.csv").dropna()
terms = Hitters.columns.drop('Salary')
Y = Hitters['Salary']
X = transform_df_for_model(Hitters[terms],terms)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=1/3, random_state=1)

# %%
Y_train.shape
# Out:
# (175,)

# %%
Y_test.shape
# Out:
# (88,)

# %%
model_lr = sm.OLS(Y_train, X_train).fit()

y_pred = model_lr.predict(X_test)
(Y_test-y_pred).abs().mean() # mean absolute error
# Out:
# np.float64(259.715288331463)

# %%
from sklearn import linear_model

# Création du modèle
clf = linear_model.Lasso(alpha=0.1)
linear_model = linear_model.LinearRegression()

for model in [clf, linear_model]:
    # Entraînement du modèle
    model.fit(X_train, Y_train)

    # Prédictions
    y_pred = model.predict(X_test)

    # Erreur absolue moyenne
    mae = (Y_test - y_pred).abs().mean()
    print("Mean Absolute Error:", mae)
# lasso classique sans gridsearch
# Out:
# Mean Absolute Error: 257.9202342821669
# Mean Absolute Error: 259.7152883314625
# /Users/passion/Documents/2025/dev_helpers/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.509e+06, tolerance: 3.630e+03
#   model = cd_fast.enet_coordinate_descent(

# %%
# find best lasso model
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LassoCV
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso

scaler = StandardScaler(with_mean=True, with_std=True)
lasso = Lasso(warm_start=True, max_iter=30000)

standard_lasso = Pipeline(steps = [('scaler',scaler),('lasso', lasso)])
X_s = scaler.fit_transform(X_train)                        

X
# Out:
#      intercept  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  \
# 0          1.0    315    81      7    24   38     39     14    3449    835
# 1          1.0    479   130     18    66   72     76      3    1624    457
# 2          1.0    496   141     20    65   78     37     11    5628   1575
# 3          1.0    321    87     10    39   42     30      2     396    101
# 4          1.0    594   169      4    74   51     35     11    4408   1133
# ..         ...    ...   ...    ...   ...  ...    ...    ...     ...    ...
# 258        1.0    497   127      7    65   48     37      5    2703    806
# 259        1.0    492   136      5    76   50     94     12    5511   1511
# 260        1.0    475   126      3    61   43     52      6    1700    433
# 261        1.0    573   144      9    85   60     78      8    3198    857
# 262        1.0    631   170      9    77   44     31     11    4908   1457
#
# ...

# %%
X_s = scaler.fit_transform(X_train)
import numpy as np
from sklearn.model_selection import KFold
n = X_s.shape[0]
lam_max = np.fabs(X_s.T.dot(Y_train - Y_train.mean())).max() / n
param_grid = {'lasso__alpha': np.exp(np.linspace(0, np.log(0.01), 100))
             * lam_max}
cv = KFold(n_splits=10, shuffle=True, random_state=1)
grid = GridSearchCV(standard_lasso, param_grid, cv=cv, scoring='neg_mean_absolute_error')
grid.fit(X_train, Y_train)
trained_lasso = grid.best_estimator_
y_pred = trained_lasso.predict(X_test)
np.fabs(Y_test - y_pred).mean() # mean absolute error
# Out:
# np.float64(235.67548374780287)

# %%
lam_max
# Out:
# np.float64(255.6575502649127)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LassoCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import median_absolute_error


Scaler = StandardScaler()

# %%
# Out:
# /Users/passion/Documents/2025/dev_helpers/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.509e+06, tolerance: 3.630e+03
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1)

# %% [markdown]
# # nerual

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchinfo import summary
from torch.utils.data import TensorDataset
from pytorch_lightning import seed_everything
seed_everything(0, workers=True)
torch.use_deterministic_algorithms(True, warn_only=True)
# Out:
# Seed set to 0

# %% [markdown]
# # clasee

# %%
class HittersModel(nn.Module):

    def __init__(self, input_size):
        super(HittersModel, self).__init__()
        self.flatten = nn.Flatten()
        self.sequential = nn.Sequential(
            nn.Linear(input_size, 50),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(50, 1))

    def forward(self, x):
        x = self.flatten(x)
        return torch.flatten(self.sequential(x))

# %%
hit_model = HittersModel(X.shape[1])
summary(hit_model, 
        input_size=X_train.shape,
        col_names=['input_size',
                   'output_size',
                   'num_params'])
# Out:
# ...
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #
# ...
# HittersModel                             [175, 20]                 [175]                     --
# ├─Flatten: 1-1                           [175, 20]                 [175, 20]                 --
# ├─Sequential: 1-2                        [175, 20]                 [175, 1]                  --
# │    └─Linear: 2-1                       [175, 20]                 [175, 50]                 1,050
# │    └─ReLU: 2-2                         [175, 50]                 [175, 50]                 --
# │    └─Dropout: 2-3                      [175, 50]                 [175, 50]                 --
# │    └─Linear: 2-4                       [175, 50]                 [175, 1]                  51
# ...
# Total params: 1,101
# Trainable params: 1,101
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.19
# ...
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.07
# Params size (MB): 0.00
# ...

# %%
from torch.utils.data import DataLoader, TensorDataset

# %%
X_train_t = torch.tensor(X_train.values.astype(np.float32))
Y_train_t = torch.tensor(Y_train.values.astype(np.float32))
hit_train = TensorDataset(X_train_t, Y_train_t)

# %%
X_test_t = torch.tensor(X_test.values.astype(np.float32))
Y_test_t = torch.tensor(Y_test.values.astype(np.float32))
hit_test = TensorDataset(X_test_t, Y_test_t)

# %%
from torchvision import transforms
from torch.utils.data import TensorDataset

from torchmetrics import Accuracy

from pytorch_lightning import (LightningModule,
                               LightningDataModule)
from pytorch_lightning.utilities.rank_zero import rank_zero_only
from pytorch_lightning.callbacks import Callback

class SimpleDataModule(LightningDataModule):

    def __init__(self,
                 train_dataset,
                 test_dataset,
                 batch_size=32,
                 num_workers=0,
                 persistent_workers=True,
                 validation=None,
                 seed=0):

        super(SimpleDataModule, self).__init__()

        ntrain = len(train_dataset)
        if type(validation) == float:
            nvalidation = int(validation * len(train_dataset))
        elif type(validation) == int:
            nvalidation = validation
        elif validation is None:
            nvalidation = 0

        if isinstance(validation, Dataset):
            (self.train_dataset,
             self.validation_dataset) = (train_dataset,
                                         validation)
        else:
            (self.train_dataset,
             self.validation_dataset) = random_split(train_dataset,
                                                     [ntrain - nvalidation,
                                                      nvalidation],
                                                     generator=Generator().manual_seed(seed))
                
        self.test_dataset = test_dataset
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.persistent_workers = persistent_workers and num_workers > 0
        self.seed = seed
        
    def train_dataloader(self):
        return DataLoader(self.train_dataset,
                          shuffle=True,
                          batch_size=self.batch_size,
                          num_workers=self.num_workers,
                          persistent_workers=self.persistent_workers)

    # for validation, test and predict
    # we load the entire data at once in this
    # simple module. otherwise metrics get averaged
    # over minibatch

    def val_dataloader(self):
        return DataLoader(self.validation_dataset,
                          shuffle=False,
                          batch_size=self.batch_size,
                          num_workers=self.num_workers,
                          persistent_workers=self.persistent_workers)

    def test_dataloader(self):
        return DataLoader(self.test_dataset,
                          batch_size=self.batch_size,
                          num_workers=self.num_workers,
                          persistent_workers=self.persistent_workers)

    def predict_dataloader(self):
        return DataLoader(self.test_dataset,
                          batch_size=len(self.test_dataset),
                          num_workers=self.num_workers,
                          persistent_workers=self.persistent_workers)

    @staticmethod
    def fromarrays(*arrays,
                   test=0,
                   validation=0,
                   batch_size=32,
                   num_workers=0,
                   persistent_workers=True,
                   test_as_validation=False,
                   seed=0):

        tensor_ds = TensorDataset(*[tensor(arr) for arr in arrays])
        npts = len(tensor_ds)
        if type(test) == float:
            test = int(test*npts)
        if type(validation) == float:
            validation = int(validation*npts)
        if npts <= test + validation:
            raise ValueError('Total test and validation requested exceeds size of dataset: no data left for training.')
        train_ds, test_ds, valid_ds = random_split(tensor_ds,
                                                   [npts - test - validation,
                                                    test,
                                                    validation],
                                                   generator=Generator().manual_seed(seed))
        if test_as_validation:
            valid_ds = test_ds
            if validation != 0:
                warnings.warn('Validation set not empty but `test_as_validation` is True. If using test set for validation set `validation=0`.')

        return SimpleDataModule(train_ds,
                                test_ds,
                                validation=valid_ds,
                                batch_size=batch_size,
                                num_workers=num_workers,
                                persistent_workers=persistent_workers,
                                seed=seed)

class SimpleModule(LightningModule):

    """
    A simple `pytorch_lightning` module for regression problems.
    """

    def __init__(self,
                 model,
                 loss,
                 optimizer=None,
                 metrics={},
                 on_epoch=True,
                 pre_process_y_for_metrics=lambda y: y):

        super(SimpleModule, self).__init__()

        self.model = model
        self.loss = loss or nn.MSELoss()
        optimizer = optimizer or RMSprop(model.parameters())
        self._optimizer = optimizer
        self.metrics = metrics
        self.on_epoch = on_epoch
        self.pre_process_y_for_metrics = pre_process_y_for_metrics
        
    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self.forward(x)
        loss = self.loss(preds, y)
        self.log("train_loss",
                 loss,
                 on_epoch=self.on_epoch,
                 on_step=False)

        y_ = self.pre_process_y_for_metrics(y)
        for _metric in self.metrics.keys():
            self.log(f"train_{_metric}",
                     self.metrics[_metric](preds, y_),
                     on_epoch=self.on_epoch)
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch

    @rank_zero_only
    def validation_step(self, batch, batch_idx):
        x, y = batch

    def predict_step(self, batch, batch_idx):
        x, y = batch
        return y, self.forward(x)

    def configure_optimizers(self):
        return self._optimizer

    @staticmethod
    def regression(model,
                   **kwargs):
        loss = nn.MSELoss()
        return SimpleModule(model,
                            loss,
                            **kwargs)

    @staticmethod
    def binary_classification(model,
                              metrics={},
                              device=None,
                              **kwargs):
        loss = nn.BCEWithLogitsLoss()
        if 'accuracy' not in metrics:
            metrics['accuracy'] = Accuracy()
        if device is not None:
            for key, metric in metrics:
                metrics[key] = metric.to(device)
        return SimpleModule(model,
                            loss,
                            metrics=metrics,
                            pre_process_y_for_metrics = lambda x: x.int(),
                            **kwargs)

    @staticmethod
    def classification(model,
                       metrics={},
                       device=None,
                       **kwargs):
        loss = nn.CrossEntropyLoss()
        if 'accuracy' not in metrics:
            metrics['accuracy'] = Accuracy()
        if device is not None:
            for key, metric in metrics:
                metrics[key] = metric.to(device)
        return SimpleModule(model,
                            loss,
                            metrics=metrics,
                            **kwargs)
def rec_num_workers():

    """

    Get a suggested number of workers for data loaders
    in a `pytorch_lightning` data module.

    Based on 

    https://github.com/pytorch/pytorch/blob/fb0f285638338da93960d2b654a59c9639671fc0/torch/utils/data/dataloader.py#L478-L505
    """

    max_num_worker_suggest = None
    cpuset_checked = False
    if hasattr(os, 'sched_getaffinity'):
        try:
            max_num_worker_suggest = len(os.sched_getaffinity(0))
            cpuset_checked = True
        except Exception:
            pass
    if max_num_worker_suggest is None:
        # os.cpu_count() could return Optional[int]
        # get cpu count first and check None in order to satify mypy check
        cpu_count = os.cpu_count()
        if cpu_count is not None:
            max_num_worker_suggest = cpu_count

    return max_num_worker_suggest

# %%
import os
max_num_workers = rec_num_workers()
max_num_workers
# Out:
# 8

# %%
from torch.utils.data import Dataset

# %%
hit_dm = SimpleDataModule(hit_train,
                          hit_test,
                          batch_size=32,
                          num_workers=min(4, max_num_workers),
                          validation=hit_test)

# %%
# Out:
# 8
